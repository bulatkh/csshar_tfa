# %%
import pandas as pd
import numpy as np

from utils.xai_utils import plot_ts
import matplotlib.pyplot as plt

from utils.augmentation_utils import *
import os

# %%
example = pd.read_csv('./sampled_data/mobi_act/mobi_act/train/subject1_3_a2_5.csv')
example_acc = np.array(example)[:,:3]

# %%
os.makedirs('./aug_vis', exist_ok=True)

# %%
plot_ts(example_acc.T, figsize=(3.5, 4), subtitles=['acc X', 'acc Y', 'acc Z', 'gyro X', 'gyro Y', 'gyro Z'], save='./aug_vis/original.pdf')
# Out:
# /home/bulat/anaconda3/envs/bulat_env/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
jittered = Jittering(0.5)(example_acc)
plot_ts(jittered.T, figsize=(3.5, 4), subtitles=['acc X', 'acc Y', 'acc Z', 'gyro X', 'gyro Y', 'gyro Z'], save='./aug_vis/jittered.pdf')
# Out:
# /home/bulat/anaconda3/envs/bulat_env/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
scaled = Scaling(0.5)(example_acc)
plot_ts(scaled.T, figsize=(3.5, 4), subtitles=['acc X', 'acc Y', 'acc Z', 'gyro X', 'gyro Y', 'gyro Z'], save='./aug_vis/scaled.pdf')
# Out:
# /home/bulat/anaconda3/envs/bulat_env/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
shuffled = ChannelShuffle()(example_acc)
plot_ts(shuffled.T, figsize=(3.5, 4), subtitles=['acc X', 'acc Y', 'acc Z', 'gyro X', 'gyro Y', 'gyro Z'], save='./aug_vis/shuffled.pdf')
# Out:
# /home/bulat/anaconda3/envs/bulat_env/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
rotation = Rotation()(example_acc)
plot_ts(rotation.T, figsize=(3.5, 4), subtitles=['acc X', 'acc Y', 'acc Z', 'gyro X', 'gyro Y', 'gyro Z'], save='./aug_vis/rotated.pdf')
# Out:
# /home/bulat/anaconda3/envs/bulat_env/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)

# %%
permuted = Permutation()(example_acc)
plot_ts(permuted.T, figsize=(3.5, 4), subtitles=['acc X', 'acc Y', 'acc Z', 'gyro X', 'gyro Y', 'gyro Z'], save='./aug_vis/permuted.pdf')
# Out:
# /home/bulat/anaconda3/envs/bulat_env/lib/python3.7/site-packages/seaborn/timeseries.py:183: UserWarning: The `tsplot` function is deprecated and will be removed in a future release. Please update your code to use the new `lineplot` function.
#   warnings.warn(msg, UserWarning)
